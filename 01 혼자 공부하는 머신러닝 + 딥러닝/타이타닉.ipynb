# %%
import pandas as pd
import numpy as np
train = pd.read_csv('train.csv')
test = pd.read_csv('test.csv')
# 인덱스는 0부터 시작한다!
# Pclass=1 퍼스크 클래스, 숫자가 커질수록 등급이 낮은 좌석
# Sibsp: 가족 구성원의 탑승 여부
# Parch: 부모님이나 자식의 탑승 여부
# NaN: None 
train.head(20)
# Out:
#     PassengerId  Survived  Pclass  \
# 0             1         0       3
# 1             2         1       1
# 2             3         1       3
# 3             4         1       1
# 4             5         0       3
# 5             6         0       3
# 6             7         0       1
# 7             8         0       3
# 8             9         1       3
# 9            10         1       2
# 10           11         1       3
# 11           12         1       1
# 12           13         0       3
# 13           14         0       3
# 14           15         0       3
# 15           16         1       2
# 16           17         0       3
# 17           18         1       2
# 18           19         0       3
# 19           20         1       3
#
#                                                  Name     Sex   Age  SibSp  \
# 0                             Braund, Mr. Owen Harris    male  22.0      1
# 1   Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# ...

# %%
test.head()
# survived columns가 없다.
# shape는 행과 열을 의미한다.
train.shape
test.shape
# Out:
# (418, 11)

# %%
train.info()
# 유살된 정보들을 확인할 수 있다. 머신러닝하기 전에 해결해야 하는 문제들이다.
# 그건 바로 feature engineering
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 891 entries, 0 to 890
# Data columns (total 12 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   PassengerId  891 non-null    int64
#  1   Survived     891 non-null    int64
#  2   Pclass       891 non-null    int64
#  3   Name         891 non-null    object
#  4   Sex          891 non-null    object
#  5   Age          714 non-null    float64
#  6   SibSp        891 non-null    int64
#  7   Parch        891 non-null    int64
#  8   Ticket       891 non-null    object
#  9   Fare         891 non-null    float64
#  10  Cabin        204 non-null    object
#  11  Embarked     889 non-null    object
# dtypes: float64(2), int64(5), object(5)
# memory usage: 83.7+ KB

# %%
test.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 418 entries, 0 to 417
# Data columns (total 11 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   PassengerId  418 non-null    int64
#  1   Pclass       418 non-null    int64
#  2   Name         418 non-null    object
#  3   Sex          418 non-null    object
#  4   Age          332 non-null    float64
#  5   SibSp        418 non-null    int64
#  6   Parch        418 non-null    int64
#  7   Ticket       418 non-null    object
#  8   Fare         417 non-null    float64
#  9   Cabin        91 non-null     object
#  10  Embarked     418 non-null    object
# dtypes: float64(2), int64(4), object(5)
# memory usage: 36.1+ KB

# %%
train.isnull().sum()
# Embarked: 승선하다, 탑승하다.-> 어느 항구에서 탑승했는지?
# Out:
# PassengerId      0
# Survived         0
# Pclass           0
# Name             0
# Sex              0
# Age            177
# SibSp            0
# Parch            0
# Ticket           0
# Fare             0
# Cabin          687
# Embarked         2
# dtype: int64

# %%
import seaborn as sns
# %matplotlib inline
# %matplotlib inline: 그래프를 생성하는 코드 바로 아래에 그래프를 바로 출력하도록 한다.
import matplotlib.pyplot as plt

# %%
# Feature Engineering
# Feature: 칼럼의 값들. text를 모두 number로 변환시켜 모델이 이해하기 쉽도록 setting

# %%
train_test_data = [train, test]
# 두 data를 묶어서 한 번에 수정할 수 있다.

for dataset in train_test_data:
    dataset['Title'] = dataset['Name'].str.extract(' ([A-Za-z]+)\.', expand=False)

# train 데이터와 test 데이터에 똑같은 작업을 반복하여 적용하겠다. : for ~ in ~
# for 변수 in 바구니: 실행할 코
# Name 열에서 특정 패턴을 extract 하겠다.
# 공백으로 시작하고, 알파벳이 하나 이상 나오며, 마침표로 끝나는 부분을 찾으라.
# 정규 표현식에 따라 원하는 데이터를 추출하는 형태
# 그리고 그렇게 추출한 Mr, Miss 값을 Title 이라는 col에 저장한다.
    
# train_test_data.head() 는 list 형태이므로, pandas의 head()를 사용할 수 없다.

train_test_data[0].head()
# Out:
#    PassengerId  Survived  Pclass  \
# 0            1         0       3
# 1            2         1       1
# 2            3         1       3
# 3            4         1       1
# 4            5         0       3
#
#                                                 Name     Sex   Age  SibSp  \
# 0                            Braund, Mr. Owen Harris    male  22.0      1
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                             Heikkinen, Miss. Laina  female  26.0      0
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                           Allen, Mr. William Henry    male  35.0      0
#
#    Parch            Ticket     Fare Cabin Embarked Title
# 0      0         A/5 21171   7.2500   NaN        S    Mr
# 1      0          PC 17599  71.2833   C85        C   Mrs
# 2      0  STON/O2. 3101282   7.9250   NaN        S  Miss
# 3      0            113803  53.1000  C123        S   Mrs
# ...
